# %%
import torch
from ultralytics import YOLO

# %%
from code_programm.path import get_path_to_dataset_for_yolo_line, get_path_model, get_path_weight_model

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name())
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
# model = YOLO(get_path_model('yolov9c-seg.pt'))
model = YOLO('yolov9c-seg.pt')

# %%
# model = YOLO(get_path_weight_model('yolov9c-seg.pt'))

# %%
model.train(data=get_path_to_dataset_for_yolo_line(), epochs=160, device='cuda:0', plots=True, save=True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.22 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2  Python-3.11.8 torch-2.2.2+cu118 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264MiB)
# ...

# %%
model.save(get_path_weight_model('yolov9c-seg.pt'))
