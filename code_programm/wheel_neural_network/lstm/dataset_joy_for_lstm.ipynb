# %%
import pandas as pd

from code_programm.path import get_path_wheel_net_weight

# %%
wheel_ets_train_y_ = pd.read_csv(r'C:\PycharmProjects\ETS_Autopilot\dataset_for_wheel_nn\y_train_wheel.csv')
len(wheel_ets_train_y_)
# Out:
# 13038

# %%
wheel_ets_train_y_.describe()
# Out:
#               value
# count  13038.000000
# mean       0.005132
# std        0.031777
# min       -0.143188
# 25%       -0.010376
# 50%        0.001373
# 75%        0.014801
# max        0.153259

# %%
new_wheel_ets_train_y = pd.DataFrame(columns=[0, 1])

# %%
for i in range(len(wheel_ets_train_y_)-1):
    new_wheel_ets_train_y.loc[i] = [
        wheel_ets_train_y_.iloc[i][wheel_ets_train_y_.columns[0]],  # Исправлено для явного обращения к столбцу
        wheel_ets_train_y_.iloc[i + 1][wheel_ets_train_y_.columns[0]]
    ]

# %%
new_wheel_ets_train_y.loc[0]
# Out:
# 0    0.00528
# 1    0.00528
# Name: 0, dtype: float64

# %%
new_wheel_ets_train_y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13037 entries, 0 to 13036
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13037 non-null  float64
#  1   1       13037 non-null  float64
# dtypes: float64(2)
# memory usage: 821.6 KB

# %%
new_wheel_ets_train_y.to_csv(get_path_wheel_net_weight('y_train_for_lstm_wheel_4.csv'), index=False)
