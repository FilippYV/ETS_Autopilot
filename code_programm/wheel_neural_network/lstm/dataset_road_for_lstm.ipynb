# %%
import pandas as pd

from code_programm.path import get_path_wheel_net_weight

# %%
wheel_ets_train_x_ = pd.read_csv(get_path_wheel_net_weight('X_train_road.csv'))
wheel_ets_train_x_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13038 entries, 0 to 13037
# Columns: 12288 entries, 0 to 12287
# dtypes: float64(12288)
# memory usage: 1.2 GB

# %%
wheel_ets_train_x_ = wheel_ets_train_x_.drop(wheel_ets_train_x_.tail(1).index, axis = 0)
wheel_ets_train_x_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13037 entries, 0 to 13036
# Columns: 12288 entries, 0 to 12287
# dtypes: float64(12288)
# memory usage: 1.2 GB

# %%
wheel_ets_train_x_.to_csv(get_path_wheel_net_weight('X_train_for_lstm_road_version_4.csv'), index=False)
