# %%
import pandas as pd

from code_programm.path import get_path_wheel_net_weight

# %%
wheel_ets_train_x_ = pd.read_csv(get_path_wheel_net_weight('X_train_speed.csv'))
wheel_ets_train_x_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13038 entries, 0 to 13037
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   speed   13038 non-null  int64
# dtypes: int64(1)
# memory usage: 102.0 KB

# %%
wheel_ets_train_x_ = wheel_ets_train_x_.drop(wheel_ets_train_x_.tail(1).index, axis = 0)
wheel_ets_train_x_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13037 entries, 0 to 13036
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   speed   13037 non-null  int64
# dtypes: int64(1)
# memory usage: 102.0 KB

# %%
wheel_ets_train_x_.to_csv(get_path_wheel_net_weight('X_train_for_lstm_speed_version_4.csv'), index=False)
