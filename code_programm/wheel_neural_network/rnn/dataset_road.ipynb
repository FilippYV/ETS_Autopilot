# %%
import os
import time
from pathlib import Path

import cv2
import pandas as pd
import torch
import torch.nn.functional as F
from natsort import natsorted
from ultralytics import YOLO

from code_programm.path import get_path_weight_model

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name())
model = YOLO(get_path_weight_model('best.pt'))
# Out:
# 1
# NVIDIA GeForce GTX 1080 Ti

# %%
wheel_ets_train_x = pd.DataFrame(columns=[i for i in range(96 * 128)])

# %%
folder_path = Path('D:\Dataset_for_autopilot')
files_and_folders = os.listdir(folder_path)

# Фильтруем только папки
folders = [f for f in files_and_folders if os.path.isdir(os.path.join(folder_path, f))]

# Сортируем папки по дате изменения
sorted_folders = sorted(folders, key=lambda x: os.path.getmtime(os.path.join(folder_path, x)), reverse=True)

# Выводим список папок
print("Папки в папке {} отсортированы по дате изменения: ".format(folder_path))
for folder in sorted_folders:
    print(folder)
# Out:
# Папки в папке D:\Dataset_for_autopilot отсортированы по дате изменения:
# 2024-04-02 19-12-38
# 2024-04-02 19-12-21
# 2024-04-02 19-11-55
# 2024-04-02 19-09-18
# 2024-04-02 19-07-31
# 2024-04-02 19-05-23
# 2024-04-02 19-01-56
# 2024-04-02 19-00-41
# 2024-04-02 18-58-46
# 2024-04-02 18-57-24
# 2024-04-02 18-55-25
# new
# 2024-04-01 08-19-11
# 2024-04-01 08-18-41
# 2024-04-01 08-18-29
# 2024-04-01 08-18-18
# 2024-04-01 08-15-21
# 2024-04-01 08-13-16
# 2024-04-01 08-12-10
# 2024-04-01 08-10-13
# 2024-04-01 08-08-58
# 2024-04-01 08-07-13
# 2024-04-01 08-05-14
# 2024-04-01 08-03-03
# 2024-04-01 08-01-05
# 2024-04-01 07-58-48
# 2024-04-01 07-55-54
# 2024-04-01 07-51-15
# 2024-04-01 07-47-21
# 2024-04-01 07-42-36
# 2024-04-01 07-41-03
# 2024-04-01 07-36-51
# 2024-04-01 07-34-54
# 2024-04-01 07-32-35
# 2024-04-01 07-29-56
# 2024-04-01 07-26-37
# num
# 2024-03-31 03-29-46
# 2024-03-31 03-28-05
# 2024-03-31 03-26-14
# 2024-03-31 03-24-22
# 2024-03-31 03-22-07
# 2024-03-31 03-17-11
# 2024-03-31 03-11-36
# 2024-03-31 03-05-57
# numbers
# Новая папка
# 2024-03-29 07-04-10
# 2024-03-29 07-01-32
# 2024-03-29 06-57-45
# 2024-03-28 05-07-19
# 2024-03-27 00-11-26
# 2024-03-27 00-00-05
# 2024-02-29 19-40-13
# 2024-02-29 17-28-08
# 2024-02-29 15-46-10
# 2024-02-27 06-09-465
# 2024-02-27 04-45-43
# 2024-02-27 03-56-41
# 2024-02-27 03-51-46
# 2024-02-26 23-54-36
# 2024-02-26 23-45-25
# 2024-02-26 19-01-09
# 2024-02-25 06-47-15
# 2024-02-25 06-00-47
# 2024-02-25 02-41-10

# %%
paths = [
    r'D:\Dataset_for_autopilot\2024-04-02 19-11-55',
    r'D:\Dataset_for_autopilot\2024-04-02 19-09-18',
    r'D:\Dataset_for_autopilot\2024-04-02 19-07-31',
    r'D:\Dataset_for_autopilot\2024-04-02 19-05-23',
    r'D:\Dataset_for_autopilot\2024-04-02 19-01-56',
    r'D:\Dataset_for_autopilot\2024-04-02 19-00-41',
    r'D:\Dataset_for_autopilot\2024-04-02 18-58-46',
    r'D:\Dataset_for_autopilot\2024-04-02 18-57-24',
    r'D:\Dataset_for_autopilot\2024-04-02 18-55-25',
]

# %%
mass_results = []

for num_path in paths:
    path_i = os.path.join(num_path, f'road')
    if os.path.exists(f'{path_i}') and os.path.isdir(f'{path_i}'):
        png_files = [os.path.join(path_i, file) for file in os.listdir(path_i) if file.endswith('.png')]
        print("Полные пути к файлам в папке:")
        png_files = natsorted(png_files)
        print(png_files[0])
    else:
        print("Указанный путь не существует или не является папкой.")

    start_time = time.time()
    length = len(wheel_ets_train_x)

    combined_mask_new = torch.zeros((1, 1, 96, 128), device='cuda')

    for file in png_files:
        bgra_image = cv2.imread(file, cv2.IMREAD_UNCHANGED)
        bgr_image = cv2.cvtColor(bgra_image, cv2.COLOR_BGRA2BGR)
        results = model(bgr_image,
                        # imgsz=576,
                        conf=0.6,
                        # show=True,
                        device='cuda',
                        verbose=False)
        if results[0].masks is not None:
            combined_mask_new.zero_()
            for i in results[0].masks.data:
                combined_mask_new += F.interpolate(i.unsqueeze(0).unsqueeze(0), size=(96, 128), mode='bilinear',
                                                   align_corners=True)

        combined_tensor = combined_mask_new

        wheel_ets_train_x.loc[len(wheel_ets_train_x)] = combined_tensor[0][0].flatten().detach().cpu().numpy()

    print('Изображений:', len(wheel_ets_train_x) - length, '\nСек:', time.time() - start_time, '\nCек\изображение:',
          (time.time() - start_time) / (len(wheel_ets_train_x) - length), '\n')
print('Всего:', len(wheel_ets_train_x))
cv2.destroyAllWindows()
# Out:
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 19-11-55\road\2024-04-02 19-11-55_0.png
# Изображений: 231
# Сек: 8.272545576095581
# Cек\изображение: 0.03581188561080338
#
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 19-09-18\road\2024-04-02 19-09-18_0.png
# Изображений: 591
# Сек: 27.133277654647827
# Cек\изображение: 0.04591079129382035
#
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 19-07-31\road\2024-04-02 19-07-31_0.png
# Изображений: 1817
# Сек: 101.41764187812805
# Cек\изображение: 0.055815983422194855
#
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 19-05-23\road\2024-04-02 19-05-23_0.png
# Изображений: 1436
# Сек: 110.34595775604248
# Cек\изображение: 0.0768425889666034
#
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 19-01-56\road\2024-04-02 19-01-56_0.png
# Изображений: 3705
# Сек: 340.748242855072
# Cек\изображение: 0.09196983612822457
#
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 19-00-41\road\2024-04-02 19-00-41_0.png
# Изображений: 812
# Сек: 102.35415768623352
# Cек\изображение: 0.1260519183327999
#
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 18-58-46\road\2024-04-02 18-58-46_0.png
# Изображений: 1572
# Сек: 224.09640979766846
# Cек\изображение: 0.1425549680646746
#
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 18-57-24\road\2024-04-02 18-57-24_0.png
# Изображений: 895
# Сек: 143.66475820541382
# Cек\изображение: 0.1605192829110769
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-02 18-55-25\road\2024-04-02 18-55-25_0.png
# Изображений: 1723
# Сек: 296.18352794647217
# Cек\изображение: 0.17189990014304826
#
# Всего: 12782

# %%
wheel_ets_train_x = wheel_ets_train_x.drop(wheel_ets_train_x.tail(1).index, axis = 0)
wheel_ets_train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12781 entries, 0 to 12780
# Columns: 12288 entries, 0 to 12287
# dtypes: float32(12288)
# memory usage: 599.2 MB

# %%
wheel_ets_train_x.to_csv(r'C:\PycharmProjects\ETS_Autopilot\dataset_for_wheel_nn\X_train_road_rnn.csv', index=False)
