# %%
import os
import pandas as pd

# %%
wheel_ets_train_y = pd.DataFrame(columns=['value'])

# %%
paths = [
    r'D:\Dataset_for_autopilot\2024-04-02 19-11-55',
    r'D:\Dataset_for_autopilot\2024-04-02 19-09-18',
    r'D:\Dataset_for_autopilot\2024-04-02 19-07-31',
    r'D:\Dataset_for_autopilot\2024-04-02 19-05-23',
    r'D:\Dataset_for_autopilot\2024-04-02 19-01-56',
    r'D:\Dataset_for_autopilot\2024-04-02 19-00-41',
    r'D:\Dataset_for_autopilot\2024-04-02 18-58-46',
    r'D:\Dataset_for_autopilot\2024-04-02 18-57-24',
    r'D:\Dataset_for_autopilot\2024-04-02 18-55-25',
]

# %%
for path in paths:
    path_i = os.path.join(path, f'log.csv')
    with open(path_i, 'r') as file:
        for line in file:
            lines = line.strip().split(',')
            wheel_ets_train_y.loc[lines[0]] = [lines[1]]

# %%
len(wheel_ets_train_y)
# Out:
# 12782

# %%
new_wheel_ets_train_y = pd.DataFrame(columns=[0, 1])

# %%
for i in range(len(wheel_ets_train_y)-1):
    new_wheel_ets_train_y.loc[i] = [
        wheel_ets_train_y.iloc[i][wheel_ets_train_y.columns[0]],  # Исправлено для явного обращения к столбцу
        wheel_ets_train_y.iloc[i + 1][wheel_ets_train_y.columns[0]]
    ]

# %%
new_wheel_ets_train_y.to_csv(r'C:\PycharmProjects\ETS_Autopilot\dataset_for_wheel_nn\y_train_wheel_rnn.csv', index=False)
