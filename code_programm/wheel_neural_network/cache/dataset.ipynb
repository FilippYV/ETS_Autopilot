# %%
import pandas as pd

# %%
X = pd.read_csv(r'C:\PycharmProjects\ETS_Autopilot\dataset_for_wheel_nn\X_train_road.csv')
S = pd.read_csv(r'C:\PycharmProjects\ETS_Autopilot\dataset_for_wheel_nn\X_train_speed.csv')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7861 entries, 0 to 7860
# Columns: 16384 entries, 0 to 16383
# dtypes: float64(16384)
# memory usage: 982.6 MB

# %%
S.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7861 entries, 0 to 7860
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   speed   7861 non-null   int64
# dtypes: int64(1)
# memory usage: 61.5 KB

# %%
combined_df = pd.concat([X, S], axis=1)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7861 entries, 0 to 7860
# Columns: 16385 entries, 0 to speed
# dtypes: float64(16384), int64(1)
# memory usage: 982.7 MB

# %%
combined_df.to_csv(r'C:\PycharmProjects\ETS_Autopilot\static\weight_model\X_train.csv', index=False)
