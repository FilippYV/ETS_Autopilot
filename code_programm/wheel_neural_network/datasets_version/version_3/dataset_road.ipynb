# %%
import os
import time
from pathlib import Path

import cv2
import pandas as pd
import torch
import torch.nn.functional as F
from natsort import natsorted
from ultralytics import YOLO

from code_programm.path import get_path_weight_model

# %%
print(torch.cuda.device_count())
print(torch.cuda.get_device_name())
model = YOLO(get_path_weight_model('line_recognition.pt'))

# %%
wheel_ets_train_x = pd.DataFrame(columns=[i for i in range(48 * 64)])

# %%
folder_path = Path('D:\Dataset_for_autopilot')
files_and_folders = os.listdir(folder_path)

# Фильтруем только папки
folders = [f for f in files_and_folders if os.path.isdir(os.path.join(folder_path, f))]

# Сортируем папки по дате изменения
sorted_folders = sorted(folders, key=lambda x: os.path.getmtime(os.path.join(folder_path, x)), reverse=True)

# Выводим список папок
print("Папки в папке {} отсортированы по дате изменения: ".format(folder_path))
for folder in sorted_folders:
    print(os.path.join('D:\Dataset_for_autopilot', folder))
# Out:
# Папки в папке D:\Dataset_for_autopilot отсортированы по дате изменения:
# D:\Dataset_for_autopilot\2024-04-08 14-25-52
# D:\Dataset_for_autopilot\2024-04-08 14-25-43
# D:\Dataset_for_autopilot\2024-04-08 14-25-34
# D:\Dataset_for_autopilot\2024-04-08 14-25-26
# D:\Dataset_for_autopilot\2024-04-08 14-25-07
# D:\Dataset_for_autopilot\2024-04-08 14-24-51
# D:\Dataset_for_autopilot\2024-04-08 14-23-11
# D:\Dataset_for_autopilot\2024-04-08 14-20-50
# D:\Dataset_for_autopilot\2024-04-08 14-19-43
# D:\Dataset_for_autopilot\2024-04-08 14-18-55
# D:\Dataset_for_autopilot\2024-04-08 14-17-38
# D:\Dataset_for_autopilot\2024-04-08 14-15-59
# D:\Dataset_for_autopilot\2024-04-08 14-15-30
# D:\Dataset_for_autopilot\2024-04-08 14-11-02
# D:\Dataset_for_autopilot\2024-04-08 14-00-05
# D:\Dataset_for_autopilot\new 2
# D:\Dataset_for_autopilot\2024-04-02 19-12-38
# D:\Dataset_for_autopilot\2024-04-02 19-12-21
# D:\Dataset_for_autopilot\2024-04-02 19-11-55
# D:\Dataset_for_autopilot\2024-04-02 19-09-18
# D:\Dataset_for_autopilot\2024-04-02 19-07-31
# D:\Dataset_for_autopilot\2024-04-02 19-05-23
# D:\Dataset_for_autopilot\2024-04-02 19-01-56
# D:\Dataset_for_autopilot\2024-04-02 19-00-41
# D:\Dataset_for_autopilot\2024-04-02 18-58-46
# D:\Dataset_for_autopilot\2024-04-02 18-57-24
# D:\Dataset_for_autopilot\2024-04-02 18-55-25
# D:\Dataset_for_autopilot\new
# D:\Dataset_for_autopilot\2024-04-01 08-19-11
# D:\Dataset_for_autopilot\2024-04-01 08-18-41
# D:\Dataset_for_autopilot\2024-04-01 08-18-29
# D:\Dataset_for_autopilot\2024-04-01 08-18-18
# D:\Dataset_for_autopilot\2024-04-01 08-15-21
# D:\Dataset_for_autopilot\2024-04-01 08-13-16
# D:\Dataset_for_autopilot\2024-04-01 08-12-10
# D:\Dataset_for_autopilot\2024-04-01 08-10-13
# D:\Dataset_for_autopilot\2024-04-01 08-08-58
# D:\Dataset_for_autopilot\2024-04-01 08-07-13
# D:\Dataset_for_autopilot\2024-04-01 08-05-14
# D:\Dataset_for_autopilot\2024-04-01 08-03-03
# D:\Dataset_for_autopilot\2024-04-01 08-01-05
# D:\Dataset_for_autopilot\2024-04-01 07-58-48
# D:\Dataset_for_autopilot\2024-04-01 07-55-54
# D:\Dataset_for_autopilot\2024-04-01 07-51-15
# D:\Dataset_for_autopilot\2024-04-01 07-47-21
# D:\Dataset_for_autopilot\2024-04-01 07-42-36
# D:\Dataset_for_autopilot\2024-04-01 07-41-03
# D:\Dataset_for_autopilot\2024-04-01 07-36-51
# D:\Dataset_for_autopilot\2024-04-01 07-34-54
# D:\Dataset_for_autopilot\2024-04-01 07-32-35
# D:\Dataset_for_autopilot\2024-04-01 07-29-56
# D:\Dataset_for_autopilot\2024-04-01 07-26-37
# D:\Dataset_for_autopilot\num
# D:\Dataset_for_autopilot\2024-03-31 03-29-46
# D:\Dataset_for_autopilot\2024-03-31 03-28-05
# D:\Dataset_for_autopilot\2024-03-31 03-26-14
# D:\Dataset_for_autopilot\2024-03-31 03-24-22
# D:\Dataset_for_autopilot\2024-03-31 03-22-07
# D:\Dataset_for_autopilot\2024-03-31 03-17-11
# D:\Dataset_for_autopilot\2024-03-31 03-11-36
# D:\Dataset_for_autopilot\2024-03-31 03-05-57
# D:\Dataset_for_autopilot\numbers
# D:\Dataset_for_autopilot\Новая папка
# D:\Dataset_for_autopilot\2024-03-29 07-04-10
# D:\Dataset_for_autopilot\2024-03-29 07-01-32
# D:\Dataset_for_autopilot\2024-03-29 06-57-45
# D:\Dataset_for_autopilot\2024-03-28 05-07-19
# D:\Dataset_for_autopilot\2024-03-27 00-11-26
# D:\Dataset_for_autopilot\2024-03-27 00-00-05
# D:\Dataset_for_autopilot\2024-02-29 19-40-13
# D:\Dataset_for_autopilot\2024-02-29 17-28-08
# D:\Dataset_for_autopilot\2024-02-29 15-46-10
# D:\Dataset_for_autopilot\2024-02-27 06-09-465
# D:\Dataset_for_autopilot\2024-02-27 04-45-43
# D:\Dataset_for_autopilot\2024-02-27 03-56-41
# D:\Dataset_for_autopilot\2024-02-27 03-51-46
# D:\Dataset_for_autopilot\2024-02-26 23-54-36
# D:\Dataset_for_autopilot\2024-02-26 23-45-25
# D:\Dataset_for_autopilot\2024-02-26 19-01-09
# D:\Dataset_for_autopilot\2024-02-25 06-47-15
# D:\Dataset_for_autopilot\2024-02-25 06-00-47
# D:\Dataset_for_autopilot\2024-02-25 02-41-10

# %%
paths = [
    r'D:\Dataset_for_autopilot\2024-04-08 14-25-52',
    r'D:\Dataset_for_autopilot\2024-04-08 14-25-43',
    r'D:\Dataset_for_autopilot\2024-04-08 14-25-34',
    r'D:\Dataset_for_autopilot\2024-04-08 14-25-26',
    r'D:\Dataset_for_autopilot\2024-04-08 14-25-07',
    r'D:\Dataset_for_autopilot\2024-04-08 14-24-51',
    r'D:\Dataset_for_autopilot\2024-04-08 14-23-11',
    r'D:\Dataset_for_autopilot\2024-04-08 14-20-50',
    r'D:\Dataset_for_autopilot\2024-04-08 14-19-43',
    r'D:\Dataset_for_autopilot\2024-04-08 14-18-55',
    r'D:\Dataset_for_autopilot\2024-04-08 14-17-38',
    r'D:\Dataset_for_autopilot\2024-04-08 14-15-59',
    r'D:\Dataset_for_autopilot\2024-04-08 14-15-30',
    r'D:\Dataset_for_autopilot\2024-04-08 14-11-02',
]

# %%
paths = [
    r'D:\Dataset_for_autopilot\2024-04-08 14-00-05',
]

# %%
mass_results = []

for num_path in paths:
    path_i = os.path.join(num_path, f'road')
    if os.path.exists(f'{path_i}') and os.path.isdir(f'{path_i}'):
        png_files = [os.path.join(path_i, file) for file in os.listdir(path_i) if file.endswith('.png')]
        print("Полные пути к файлам в папке:")
        png_files = natsorted(png_files)
        print(png_files[0])
    else:
        print("Указанный путь не существует или не является папкой.")

    start_time = time.time()
    length = len(wheel_ets_train_x)

    combined_mask_old = torch.zeros((1, 1, 48, 64), device='cuda')
    combined_mask_new = torch.zeros((1, 1, 48, 64), device='cuda')

    for file in png_files:
        bgra_image = cv2.imread(file, cv2.IMREAD_UNCHANGED)
        bgr_image = cv2.cvtColor(bgra_image, cv2.COLOR_BGRA2BGR)
        results = model(bgr_image,
                        conf=0.3,
                        # show=True,
                        device='cuda:0',
                        verbose=False)
        if results[0].masks is not None:
            combined_mask_old = combined_mask_new * 0.4 + combined_mask_new * 0.6
            combined_mask_new.zero_()
            for i in results[0].masks.data:
                combined_mask_new += F.interpolate(i.unsqueeze(0).unsqueeze(0), size=(48, 64), mode='bilinear',
                                                   align_corners=True)

        combined_tensor = combined_mask_old + combined_mask_new

        wheel_ets_train_x.loc[len(wheel_ets_train_x)] = combined_tensor[0][0].flatten().detach().cpu().numpy()
    wheel_ets_train_x = wheel_ets_train_x.drop(wheel_ets_train_x.tail(1).index, axis=0)

    print('Изображений:', len(wheel_ets_train_x) - length, '\nСек:', time.time() - start_time, '\nCек\изображение:',
          (time.time() - start_time) / (len(wheel_ets_train_x) - length), '\n')
print('Всего:', len(wheel_ets_train_x))
cv2.destroyAllWindows()
# Out:
# Полные пути к файлам в папке:
# D:\Dataset_for_autopilot\2024-04-08 14-00-05\road\2024-04-08 14-00-05_0.png
# Изображений: 17050
# Сек: 1036.5968043804169
# Cек\изображение: 0.06079746653257577
#
# Всего: 17050

# %%
wheel_ets_train_x.to_csv(r'C:\PycharmProjects\ETS_Autopilot\dataset_for_wheel_nn\version_4\X_train_road_4_2.csv', index=False)

# %%
path_i = os.path.join(paths[0], f'road')
if os.path.exists(f'{path_i}') and os.path.isdir(f'{path_i}'):
    png_files = [os.path.join(path_i, file) for file in os.listdir(path_i) if file.endswith('.png')]
    png_files = natsorted(png_files)

# %%
combined_mask_old = torch.zeros((1, 1, 48, 64), device='cuda')
combined_mask_new = torch.zeros((1, 1, 48, 64), device='cuda')

# %%
for i, ii in enumerate(png_files):
    bgra_image = cv2.imread(ii, cv2.IMREAD_UNCHANGED)
    bgr_image = cv2.cvtColor(bgra_image, cv2.COLOR_BGRA2BGR)
    results = model(bgr_image,
                    conf=0.6,
                    device='cuda',
                    verbose=False,
                    # show=True
                    )

    if results[0].masks is not None:
        combined_mask_old = combined_mask_old * 0.4 + combined_mask_new * 0.6
        combined_mask_new.zero_()
        for i in results[0].masks.data:
            combined_mask_new += F.interpolate(i.unsqueeze(0).unsqueeze(0), size=(48, 64), mode='bilinear',
                                               align_corners=True)

        combined_tensor = combined_mask_old + combined_mask_new

    cv2.imshow('mask', combined_tensor[0][0].cpu().detach().numpy())
    cv2.waitKey()
        # print(combined_tensor[0][0].flatten().detach().cpu().numpy())
        # print(len(combined_tensor[0][0].flatten().detach().cpu().numpy()))
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 21
#      18         combined_tensor = combined_mask_old + combined_mask_new
#      20     cv2.imshow('mask', combined_tensor[0][0].cpu().detach().numpy())
# ---> 21     cv2.waitKey()
#      22         # print(combined_tensor[0][0].flatten().detach().cpu().numpy())
#      23         # print(len(combined_tensor[0][0].flatten().detach().cpu().numpy()))
#      24 cv2.destroyAllWindows()
#
# KeyboardInterrupt:

# %%
cv2.destroyAllWindows()
